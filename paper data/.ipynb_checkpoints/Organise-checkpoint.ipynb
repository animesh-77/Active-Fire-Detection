# %% [markdown]
# ### To extract and organise data after downloading the .zip file from the Google drive
#
# After downloading the .zip files of a continent from google drive we want to extract all indivdual scenes along with their corresponding masks, mask_derivates and metadata in individual folders.
#
# This program uses *Oceania.zip* and *Oceania_metadata.zip* that should be downloaded in a subfolder named Oceania. The paths can be changed according to the need.
#
# A new *Images* folder will be created inside the *Oceania* subfolder containing the individual scenes. Each of folder in this directory will have *Scenes*, *Masks*, *Masks_derivates* (not in every scene) and *Metadata* subfolders

# %%
import os
from zipfile import ZipFile

# %%
parent= "Oceania" # change this according to the folder you want to extract


data_path= "Oceania.zip" # extension is .zip not .rar
  
# loading the temp.zip and creating a zip object
with ZipFile(os.path.join(parent, data_path), 'r') as zObject:
  
    # Extracting all the members of the zip 
    # into a specific location.
    zObject.extractall(path="Oceania/images_rar")
    
print("DONE exctracting all image files. Please check the images_rar folder")

data_path= "Oceania_metadata.zip"
  
# loading the temp.zip and creating a zip object
with ZipFile(os.path.join(parent, data_path), 'r') as zObject:
  
    # Extracting all the members of the zip 
    # into a specific location.
    zObject.extractall(path= os.path.join(parent, "metadata_rar"))
    
print("DONE exctracting all metadata files. Please check the metadata_rar folder")
# Out:
# DONE exctracting all image files. Please check the images_rar folder
# DONE exctracting all metadata files. Please check the metadata_rar folder

# %%
file_list= os.listdir(path= os.path.join(parent, "images_rar"))

# %%
file_list
# Out:
# ['z049066.zip',
#  'z049066_masks.zip',
#  'z049066_masks_derivates.zip',
#  'z053072.zip',
#  'z053072_masks.zip',
#  'z063046.zip',
#  'z063046_masks.zip',
#  'z063046_masks_derivates.zip',
#  'z065045.zip',
#  'z065045_masks.zip',
#  'z065045_masks_derivates.zip',
#  'z067073.zip',
#  'z067073_masks.zip',
#  'z067073_masks_derivates.zip',
#  'z067090.zip',
#  'z067090_masks.zip',
#  'z067091.zip',
#  'z067091_masks.zip',
#  'z069069.zip',
#  'z069069_masks.zip',
#  'z069069_masks_derivates.zip',
#  'z069070.zip',
#  'z069070_masks.zip',
#  'z072086.zip',
#  'z072086_masks.zip',
#  'z072086_masks_derivates.zip',
#  'z072087.zip',
#  'z072087_masks.zip',
#  'z072087_masks_derivates.zip',
#  'z072088.zip',
#  'z072088_masks.zip',
#  'z072088_masks_derivates.zip',
#  'z072089.zip',
#  'z072089_masks.zip',
#  'z072089_masks_derivates.zip',
#  'z074071.zip',
#  'z074071_masks.zip',
#  'z074071_masks_derivates.zip',
#  'z074072.zip',
#  'z074072_masks.zip',
#  'z074072_masks_derivates.zip',
#  'z074073.zip',
#  'z074073_masks.zip',
#  'z074073_masks_derivates.zip',
#  'z074085.zip',
#  'z074085_masks.zip',
#  'z074085_masks_derivates.zip',
#  'z074087.zip',
#  'z074087_masks.zip',
#  'z074087_masks_derivates.zip',
#  'z074088.zip',
#  'z074088_masks.zip',
#  'z074088_masks_derivates.zip',
#  'z074089.zip',
#  'z074089_masks.zip',
#  'z074089_masks_derivates.zip',
#  'z074090.zip',
#  'z074090_masks.zip',
#  'z074090_masks_derivates.zip',
#  'z074091.zip',
#  'z074091_masks.zip',
#  'z074091_masks_derivates.zip',
#  'z075090.zip',
#  'z075090_masks.zip',
#  'z075090_masks_derivates.zip',
#  'z076091.zip',
#  'z076091_masks.zip',
#  'z076091_masks_derivates.zip',
#  'z076092.zip',
#  'z076092_masks.zip',
#  'z076092_masks_derivates.zip',
#  'z079080.zip',
#  'z079080_masks.zip',
#  'z079080_masks_derivates.zip',
#  'z081074.zip',
#  'z081074_masks.zip',
#  'z081074_masks_derivates.zip',
#  'z083068.zip',
#  'z083068_masks.zip',
#  'z083074.zip',
#  'z083074_masks.zip',
#  'z088065.zip',
#  'z088065_masks.zip',
#  'z088065_masks_derivates.zip',
#  'z088066.zip',
#  'z088066_masks.zip',
#  'z088066_masks_derivates.zip',
#  'z088080.zip',
#  'z088080_masks.zip',
#  'z088080_masks_derivates.zip',
#  'z088081.zip',
#  'z088081_masks.zip',
#  'z088081_masks_derivates.zip',
#  'z088082.zip',
#  'z088082_masks.zip',
#  'z088082_masks_derivates.zip',
#  'z090077.zip',
#  'z090077_masks.zip',
#  'z090077_masks_derivates.zip',
#  'z090078.zip',
#  'z090078_masks.zip',
#  'z090078_masks_derivates.zip',
#  'z090079.zip',
#  'z090079_masks.zip',
#  'z090079_masks_derivates.zip',
#  'z090080.zip',
#  'z090080_masks.zip',
#  'z090080_masks_derivates.zip',
#  'z090081.zip',
#  'z090081_masks.zip',
#  'z090081_masks_derivates.zip',
#  'z090084.zip',
#  'z090084_masks.zip',
#  'z090084_masks_derivates.zip',
#  'z090085.zip',
#  'z090085_masks.zip',
#  'z090090.zip',
#  'z090090_masks.zip',
#  'z090090_masks_derivates.zip',
#  'z091064.zip',
#  'z091064_masks.zip',
#  'z091068.zip',
#  'z091068_masks.zip',
#  'z091068_masks_derivates.zip',
#  'z091076.zip',
#  'z091076_masks.zip',
#  'z091076_masks_derivates.zip',
#  'z091077.zip',
#  'z091077_masks.zip',
#  'z091077_masks_derivates.zip',
#  'z091082.zip',
#  'z091082_masks.zip',
#  'z091082_masks_derivates.zip',
#  'z092068.zip',
#  'z092068_masks.zip',
#  'z092068_masks_derivates.zip',
#  'z092075.zip',
#  'z092075_masks.zip',
#  'z092076.zip',
#  'z092076_masks.zip',
#  'z092076_masks_derivates.zip',
#  'z092077.zip',
#  'z092077_masks.zip',
#  'z092077_masks_derivates.zip',
#  'z092078.zip',
#  'z092078_masks.zip',
#  'z092078_masks_derivates.zip',
#  'z092079.zip',
#  'z092079_masks.zip',
#  'z092079_masks_derivates.zip',
#  'z092080.zip',
#  'z092080_masks.zip',
#  'z092080_masks_derivates.zip',
#  'z092081.zip',
#  'z092081_masks.zip',
#  'z092081_masks_derivates.zip',
#  'z092082.zip',
#  'z092082_masks.zip',
#  'z092082_masks_derivates.zip',
#  'z092083.zip',
#  'z092083_masks.zip',
#  'z092083_masks_derivates.zip',
#  'z092084.zip',
#  'z092084_masks.zip',
#  'z092084_masks_derivates.zip',
#  'z092085.zip',
#  'z092085_masks.zip',
#  'z092085_masks_derivates.zip',
#  'z092086.zip',
#  'z092086_masks.zip',
#  'z092086_masks_derivates.zip',
#  'z092087.zip',
#  'z092087_masks.zip',
#  'z092087_masks_derivates.zip',
#  'z092088.zip',
#  'z092088_masks.zip',
#  'z092088_masks_derivates.zip',
#  'z092089.zip',
#  'z092089_masks.zip',
#  'z092089_masks_derivates.zip',
#  'z093062.zip',
#  'z093062_masks.zip',
#  'z093062_masks_derivates.zip',
#  'z093063.zip',
#  'z093063_masks.zip',
#  'z093063_masks_derivates.zip',
#  'z093064.zip',
#  'z093064_masks.zip',
#  'z093066.zip',
#  'z093066_masks.zip',
#  'z093066_masks_derivates.zip',
#  'z093074.zip',
#  'z093074_masks.zip',
#  'z093074_masks_derivates.zip',
#  'z093075.zip',
#  'z093075_masks.zip',
#  'z093075_masks_derivates.zip',
#  'z093076.zip',
#  'z093076_masks.zip',
#  'z093076_masks_derivates.zip',
#  'z093077.zip',
#  'z093077_masks.zip',
#  'z093077_masks_derivates.zip',
#  'z093078.zip',
#  'z093078_masks.zip',
#  'z093078_masks_derivates.zip',
#  'z093079.zip',
#  'z093079_masks.zip',
#  'z093079_masks_derivates.zip',
#  'z093080.zip',
#  'z093080_masks.zip',
#  'z093080_masks_derivates.zip',
#  'z093081.zip',
#  'z093081_masks.zip',
#  'z093081_masks_derivates.zip',
#  'z093083.zip',
#  'z093083_masks.zip',
#  'z093084.zip',
#  'z093084_masks.zip',
#  'z093084_masks_derivates.zip',
#  'z093085.zip',
#  'z093085_masks.zip',
#  'z093085_masks_derivates.zip',
#  'z093086.zip',
#  'z093086_masks.zip',
#  'z093086_masks_derivates.zip',
#  'z093087.zip',
#  'z093087_masks.zip',
#  'z093087_masks_derivates.zip',
#  'z094073.zip',
#  'z094073_masks.zip',
#  'z094074.zip',
#  'z094074_masks.zip',
#  'z094074_masks_derivates.zip',
#  'z094075.zip',
#  'z094075_masks.zip',
#  'z094075_masks_derivates.zip',
#  'z094076.zip',
#  'z094076_masks.zip',
#  'z094076_masks_derivates.zip',
#  'z094077.zip',
#  'z094077_masks.zip',
#  'z094077_masks_derivates.zip',
#  'z094078.zip',
#  'z094078_masks.zip',
#  'z094078_masks_derivates.zip',
#  'z094079.zip',
#  'z094079_masks.zip',
#  'z094079_masks_derivates.zip',
#  'z094080.zip',
#  'z094080_masks.zip',
#  'z094080_masks_derivates.zip',
#  'z094081.zip',
#  'z094081_masks.zip',
#  'z094081_masks_derivates.zip',
#  'z094082.zip',
#  'z094082_masks.zip',
#  'z094082_masks_derivates.zip',
#  'z094084.zip',
#  'z094084_masks.zip',
#  'z094084_masks_derivates.zip',
#  'z094085.zip',
#  'z094085_masks.zip',
#  'z094085_masks_derivates.zip',
#  'z094086.zip',
#  'z094086_masks.zip',
#  'z094086_masks_derivates.zip',
#  'z094087.zip',
#  'z094087_masks.zip',
#  'z094087_masks_derivates.zip',
#  'z096070.zip',
#  'z096070_masks.zip',
#  'z096070_masks_derivates.zip',
#  'z096071.zip',
#  'z096071_masks.zip',
#  'z096071_masks_derivates.zip',
#  'z096072.zip',
#  'z096072_masks.zip',
#  'z096072_masks_derivates.zip',
#  'z096076.zip',
#  'z096076_masks.zip',
#  'z096076_masks_derivates.zip',
#  'z096082.zip',
#  'z096082_masks.zip',
#  'z096082_masks_derivates.zip',
#  'z096084.zip',
#  'z096084_masks.zip',
#  'z096084_masks_derivates.zip',
#  'z096085.zip',
#  'z096085_masks.zip',
#  'z096085_masks_derivates.zip',
#  'z096086.zip',
#  'z096086_masks.zip',
#  'z096086_masks_derivates.zip',
#  'z097070.zip',
#  'z097070_masks.zip',
#  'z097070_masks_derivates.zip',
#  'z097076.zip',
#  'z097076_masks.zip',
#  'z097079.zip',
#  'z097079_masks.zip',
#  'z097079_masks_derivates.zip',
#  'z097083.zip',
#  'z097083_masks.zip',
#  'z097083_masks_derivates.zip',
#  'z097084.zip',
#  'z097084_masks.zip',
#  'z097084_masks_derivates.zip',
#  'z098068.zip',
#  'z098068_masks.zip',
#  'z098068_masks_derivates.zip',
#  'z098069.zip',
#  'z098069_masks.zip',
#  'z098069_masks_derivates.zip',
#  'z098070.zip',
#  'z098070_masks.zip',
#  'z098070_masks_derivates.zip',
#  'z098071.zip',
#  'z098071_masks.zip',
#  'z098071_masks_derivates.zip',
#  'z098079.zip',
#  'z098079_masks.zip',
#  'z098079_masks_derivates.zip',
#  'z098083.zip',
#  'z098083_masks.zip',
#  'z098083_masks_derivates.zip',
#  'z098085.zip',
#  'z098085_masks.zip',
#  'z098085_masks_derivates.zip',
#  'z099068.zip',
#  'z099068_masks.zip',
#  'z099068_masks_derivates.zip',
#  'z099069.zip',
#  'z099069_masks.zip',
#  'z099069_masks_derivates.zip',
#  'z099070.zip',
#  'z099070_masks.zip',
#  'z099070_masks_derivates.zip',
#  'z099073.zip',
#  'z099073_masks.zip',
#  'z099074.zip',
#  'z099074_masks.zip',
#  'z099074_masks_derivates.zip',
#  'z099081.zip',
#  'z099081_masks.zip',
#  'z099081_masks_derivates.zip',
#  'z099083.zip',
#  'z099083_masks.zip',
#  'z099083_masks_derivates.zip',
#  'z099084.zip',
#  'z099084_masks.zip',
#  'z099084_masks_derivates.zip',
#  'z100072.zip',
#  'z100072_masks.zip',
#  'z100072_masks_derivates.zip',
#  'z100073.zip',
#  'z100073_masks.zip',
#  'z100083.zip',
#  'z100083_masks.zip',
#  'z100083_masks_derivates.zip',
#  'z101071.zip',
#  'z101071_masks.zip',
#  'z101071_masks_derivates.zip',
#  'z101072.zip',
#  'z101072_masks.zip',
#  'z101072_masks_derivates.zip',
#  'z101082.zip',
#  'z101082_masks.zip',
#  'z101082_masks_derivates.zip',
#  'z103068.zip',
#  'z103068_masks.zip',
#  'z103068_masks_derivates.zip',
#  'z103069.zip',
#  'z103069_masks.zip',
#  'z103069_masks_derivates.zip',
#  'z103070.zip',
#  'z103070_masks.zip',
#  'z103070_masks_derivates.zip',
#  'z103073.zip',
#  'z103073_masks.zip',
#  'z103073_masks_derivates.zip',
#  'z103074.zip',
#  'z103074_masks.zip',
#  'z103074_masks_derivates.zip',
#  'z103075.zip',
#  'z103075_masks.zip',
#  'z103075_masks_derivates.zip',
#  'z103076.zip',
#  'z103076_masks.zip',
#  'z103076_masks_derivates.zip',
#  'z103077.zip',
#  'z103077_masks.zip',
#  'z103077_masks_derivates.zip',
#  'z103082.zip',
#  'z103082_masks.zip',
#  'z104068.zip',
#  'z104068_masks.zip',
#  'z104068_masks_derivates.zip',
#  'z104069.zip',
#  'z104069_masks.zip',
#  'z104069_masks_derivates.zip',
#  'z104070.zip',
#  'z104070_masks.zip',
#  'z104070_masks_derivates.zip',
#  'z104076.zip',
#  'z104076_masks.zip',
#  'z104076_masks_derivates.zip',
#  'z104077.zip',
#  'z104077_masks.zip',
#  'z104077_masks_derivates.zip',
#  'z104078.zip',
#  'z104078_masks.zip',
#  'z104078_masks_derivates.zip',
#  'z105068.zip',
#  'z105068_masks.zip',
#  'z105068_masks_derivates.zip',
#  'z105069.zip',
#  'z105069_masks.zip',
#  'z105069_masks_derivates.zip',
#  'z105070.zip',
#  'z105070_masks.zip',
#  'z105070_masks_derivates.zip',
#  'z105071.zip',
#  'z105071_masks.zip',
#  'z105071_masks_derivates.zip',
#  'z106068.zip',
#  'z106068_masks.zip',
#  'z106068_masks_derivates.zip',
#  'z106069.zip',
#  'z106069_masks.zip',
#  'z106069_masks_derivates.zip',
#  'z106070.zip',
#  'z106070_masks.zip',
#  'z106070_masks_derivates.zip',
#  'z106077.zip',
#  'z106077_masks.zip',
#  'z106077_masks_derivates.zip',
#  'z106078.zip',
#  'z106078_masks.zip',
#  'z107070.zip',
#  'z107070_masks.zip',
#  'z107074.zip',
#  'z107074_masks.zip',
#  'z107083.zip',
#  'z107083_masks.zip',
#  'z108070.zip',
#  'z108070_masks.zip',
#  'z108070_masks_derivates.zip',
#  'z108080.zip',
#  'z108080_masks.zip',
#  'z108083.zip',
#  'z108083_masks.zip',
#  'z108083_masks_derivates.zip',
#  'z108084.zip',
#  'z108084_masks.zip',
#  'z108084_masks_derivates.zip',
#  'z109072.zip',
#  'z109072_masks.zip',
#  'z109072_masks_derivates.zip',
#  'z109073.zip',
#  'z109073_masks.zip',
#  'z109073_masks_derivates.zip',
#  'z109081.zip',
#  'z109081_masks.zip',
#  'z109081_masks_derivates.zip',
#  'z109083.zip',
#  'z109083_masks.zip',
#  'z109084.zip',
#  'z109084_masks.zip',
#  'z110070.zip',
#  'z110070_masks.zip',
#  'z110070_masks_derivates.zip',
#  'z110082.zip',
#  'z110082_masks.zip',
#  'z110082_masks_derivates.zip',
#  'z110083.zip',
#  'z110083_masks.zip',
#  'z110083_masks_derivates.zip',
#  'z110084.zip',
#  'z110084_masks.zip',
#  'z110084_masks_derivates.zip',
#  'z112074.zip',
#  'z112074_masks.zip',
#  'z112074_masks_derivates.zip',
#  'z112075.zip',
#  'z112075_masks.zip',
#  'z112075_masks_derivates.zip',
#  'z112076.zip',
#  'z112076_masks.zip',
#  'z112079.zip',
#  'z112079_masks.zip',
#  'z112079_masks_derivates.zip',
#  'z112082.zip',
#  'z112082_masks.zip',
#  'z112082_masks_derivates.zip',
#  'z112083.zip',
#  'z112083_masks.zip',
#  'z112083_masks_derivates.zip',
#  'z112084.zip',
#  'z112084_masks.zip',
#  'z112084_masks_derivates.zip',
#  'z113076.zip',
#  'z113076_masks.zip',
#  'z113080.zip',
#  'z113080_masks.zip',
#  'z113080_masks_derivates.zip',
#  'z113081.zip',
#  'z113081_masks.zip',
#  'z113081_masks_derivates.zip',
#  'z113082.zip',
#  'z113082_masks.zip',
#  'z113082_masks_derivates.zip',
#  'z113083.zip',
#  'z113083_masks.zip',
#  'z113083_masks_derivates.zip',
#  'z113084.zip',
#  'z113084_masks.zip',
#  'z113084_masks_derivates.zip',
#  'z114074.zip',
#  'z114074_masks.zip',
#  'z114074_masks_derivates.zip',
#  'z114075.zip',
#  'z114075_masks.zip',
#  'z114075_masks_derivates.zip',
#  'z114080.zip',
#  'z114080_masks.zip',
#  'z114080_masks_derivates.zip',
#  'z115074.zip',
#  'z115074_masks.zip',
#  'z115074_masks_derivates.zip',
#  'z115075.zip',
#  'z115075_masks.zip',
#  'z115075_masks_derivates.zip',
#  'z115076.zip',
#  'z115076_masks.zip',
#  'z115077.zip',
#  'z115077_masks.zip',
#  'z115077_masks_derivates.zip',
#  'z115078.zip',
#  'z115078_masks.zip',
#  'z116078.zip',
#  'z116078_masks.zip']

# %%
current_file= ""
i=0
for index, file_name in enumerate(file_list):
    
    if not("masks" in file_name): 
        # current file is an archive of multiband images
        folder_name = file_name[:-4] # name of the file withouth the ".zip"
        
        os.makedirs(os.path.join(parent, "Images",folder_name)) 
        # make a new folder of name same as .zip file
        # this folder will have Scenes, Metadata, Masks etc. folders
        
        
        patches_rar = ZipFile(os.path.join(parent, "images_rar",file_name), 'r')
        patches_rar.extractall(path= os.path.join(parent, "Images",folder_name,"Scenes"))
        patches_rar.close()
        # extracing the mulitband scenes in Scenes folder
        
        if os.path.exists(os.path.join(parent, "images_rar",f"{folder_name}_masks.zip")):
            
            masks_rar= ZipFile(os.path.join(parent, "images_rar",f"{folder_name}_masks.zip"), 'r')
            masks_rar.extractall(path= os.path.join(parent, "Images",folder_name,"Masks"))
            masks_rar.close()
            # extracting masks inside Masks folder
            
        if os.path.exists(os.path.join(parent, "images_rar",f"{folder_name}_masks_derivates.zip")):
            
            masks_der_rar= ZipFile(os.path.join(parent, "images_rar",f"{folder_name}_masks_derivates.zip"), 'r')
            masks_der_rar.extractall(path= os.path.join(parent, "Images",folder_name,"Masks_derivates"))
            masks_der_rar.close()
            # extracting masks_derivates insider Masks_derivates folder
            
        if os.path.exists(os.path.join(parent, "metadata_rar",file_name)):
            
            meta_rar= ZipFile(os.path.join(parent, "metadata_rar",file_name), 'r')
            meta_rar.extractall(path= os.path.join(parent, "Images",folder_name,"Metadata"))
            meta_rar.close()
            # extracting metadata inside Metadata folder
            
        i+=1
            
print("DONE !", i, "Folders in Images")
# Out:
# DONE ! 190 Folders in Images
